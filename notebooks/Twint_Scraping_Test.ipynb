# %%
import twint
import nest_asyncio
nest_asyncio.apply()
import pandas as pd

# %%
#  Configure
c = twint.Config()
c.Search = "london"
c.Limit = 2 #(Increments of 20 according to documentation)
c.Store_csv = True #should store as csv file
c.Location = True
c.Output = 'tests.csv'
# c.Near = 'London'
# c.Geo = (51.509865, -0.118092, 30)
# Run
twint.run.Search(c)

# %%
data = pd.read_csv('tests.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-45-78157e69f627> in <module>
# ----> 1 data = pd.read_csv('tests.csv')
#
# ~/.pyenv/versions/3.8.6/envs/le_kingmakers/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
# ...

# %%
data.columns
# Out:
# Index(['id', 'conversation_id', 'created_at', 'date', 'time', 'timezone',
#        'user_id', 'username', 'name', 'place', 'tweet', 'language', 'mentions',
#        'urls', 'photos', 'replies_count', 'retweets_count', 'likes_count',
#        'hashtags', 'cashtags', 'link', 'retweet', 'quote_url', 'video',
#        'thumbnail', 'near', 'geo', 'source', 'user_rt_id', 'user_rt',
#        'retweet_id', 'reply_to', 'retweet_date', 'translate', 'trans_src',
#        'trans_dest'],
#       dtype='object')

# %%
data
# Out:
#                       id      conversation_id               created_at  \
# 0    1401921828126220288  1401908599836884998  2021-06-07 16:19:44 BST
# 1    1401921801731690499  1401921801731690499  2021-06-07 16:19:38 BST
# 2    1401921791371755522  1401905270096379904  2021-06-07 16:19:36 BST
# 3    1401921788968247296  1401921788968247296  2021-06-07 16:19:35 BST
# 4    1401921786065960964  1401921786065960964  2021-06-07 16:19:34 BST
# ..                   ...                  ...                      ...
# 295  1401921151509618693  1401842198132428801  2021-06-07 16:17:03 BST
# 296  1401921150704406531  1401917469971857409  2021-06-07 16:17:03 BST
# 297  1401921146166067200  1401918392613879812  2021-06-07 16:17:02 BST
# 298  1401921143905439745  1401921143905439745  2021-06-07 16:17:01 BST
# 299  1401921140809945093  1400852815237558278  2021-06-07 16:17:01 BST
#
#            date      time  timezone              user_id         username  \
# ...
